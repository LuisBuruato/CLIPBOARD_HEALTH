# %%
import pandas as pd
df = pd.read_csv('C:/Users/luisb/Desktop/CLIPBOARD_HEALTH/NH_ProviderInfo_Oct2024.csv', encoding = 'latin1')

# %%
df.isna().sum()
# Out:
# CMS Certification Number (CCN)        0
# Provider Name                         0
# Provider Address                      0
# City/Town                             0
# State                                 0
#                                   ...
# Location                              0
# Latitude                              0
# Longitude                             0
# Geocoding Footnote                14018
# Processing Date                       0
# Length: 103, dtype: int64

# %%
df.isnull()
# Out:
#        CMS Certification Number (CCN)  Provider Name  Provider Address  \
# 0                               False          False             False
# 1                               False          False             False
# 2                               False          False             False
# 3                               False          False             False
# 4                               False          False             False
# ...                               ...            ...               ...
# 14809                           False          False             False
# 14810                           False          False             False
# 14811                           False          False             False
# 14812                           False          False             False
# 14813                           False          False             False
#
#        City/Town  State  ZIP Code  Telephone Number  Provider SSA County Code  \
# ...

# %%
df.head(20)
# Out:
#    CMS Certification Number (CCN)  \
# 0                           15009
# 1                           15010
# 2                           15012
# 3                           15014
# 4                           15015
# 5                           15016
# 6                           15019
# 7                           15023
# 8                           15024
# 9                           15027
# 10                          15028
# 11                          15031
# 12                          15032
# 13                          15034
# 14                          15035
# 15                          15040
# 16                          15042
# 17                          15044
# 18                          15045
# 19                          15047
#
#                                        Provider Name  \
# 0                           BURNS NURSING HOME, INC.
# 1                     COOSA VALLEY HEALTHCARE CENTER
# 2                         HIGHLANDS HEALTH AND REHAB
# ...

# %%
import pandas as pd

# Assuming `df` is the DataFrame containing your dataset
percentage_zeros = (df == 0).mean() * 100  # Calculate percentage of zeros for each column

# Filter columns with more than 70% zeros
columns_with_70_percent_zeros = percentage_zeros[percentage_zeros > 70]

print(columns_with_70_percent_zeros)
# Out:
# Rating Cycle 1 Health Revisit Score    95.686513
# Rating Cycle 2 Health Revisit Score    95.565006
# Rating Cycle 3 Health Revisit Score    95.882274
# Number of Payment Denials              84.062373
# dtype: float64
